# %% [markdown]
# <a href="https://colab.research.google.com/github/aviraljoshi23/ImageTransformation/blob/main/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98787c90-0a19-4896-90e9-a8744972ae59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98787c90-0a19-4896-90e9-a8744972ae59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mine.jpg to mine (4).jpg
# Saving My.jpg to My (4).jpg

# %% [markdown]
# #Importing libraries

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from PIL import Image,ImageEnhance

# %%
image=cv2.imread('My.jpg',1)
cv2_imshow(image)
cv2.waitKey(0)

# %%
image2=cv2.imread('mine.jpg',1)
cv2_imshow(image2)
cv2.waitKey(0)

# %% [markdown]
# Reshapeing the Image

# %% [markdown]
# Here i have reshape the photograph to get proper understanding of image clarification

# %%
image = Image.open('My.jpg')
new_image = image.resize((400,400))
new_image.save('image_400.jpg')

# %%
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FACC1C65910>

# %% [markdown]
# #Cropping the image in the next line of code

# %% [markdown]
# Let's do cropping to bigger photo,because photograph is too big.

# %%
image2 = Image.open('mine.jpg')
box = (200,350,900,1000)
cropped_image.resize((400,400))
cropped_image = image2.crop(box)
cropped_image.save('cropped_image.jpg')
print(cropped_image.size)
# Out:
# (700, 650)

# %%
cropped_image.resize((300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACC1D99FD0>

# %%
cropped_image = Image.open('cropped_image.jpg')
red,blue,green = cropped_image.split()

print(cropped_image.mode) # Output: RGB
print(red.mode) # Output: L
print(blue.mode) # Output: L
print(green.mode)# Output: L

new_image = Image.merge("RGB",(red,green,blue))
new_image.save('new_image.jpg')

print(new_image.mode)
# Out:
# RGB
# L
# L
# L
# RGB

# %%
new_image.resize((300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACC1C72E50>

# %% [markdown]
# #Enhancing the photograph

# %%
image3 = Image.open('image_400.jpg')

contrast = ImageEnhance.Contrast(image3)
contrast.enhance(1.5).save('contrast.jpg')

# %%
new=cv2.imread('contrast.jpg',1)
cv2_imshow(new)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FACC1D927D0>
# -1

# %% [markdown]
# #Smoothing the image

# %%
gray_image = cv2.cvtColor(new,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FACC1C73B90>

# %%
inverted_image=255-gray_image
cv2_imshow(inverted_image)
cv.waitKey(2)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FACC1C8C1D0>
# -1

# %% [markdown]
# Now the next step in the process is to blur the image by using the Gaussian Function in OpenCV:

# %%
blurring=cv2.GaussianBlur(inverted_image,(21,21),5)
inverted_Blurred=255-blurring
pencil_sketch=cv2.divide(gray_image,inverted_image,scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FACC1D929D0>
# -1
